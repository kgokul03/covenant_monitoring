# %%
import PyPDF2
import re
import torch
import ollama
from openai import OpenAI

# %%
CHUNK_SIZE = 2000
CYAN = '\033[96m'
NEON_GREEN = '\033[92m'
RESET_COLOR = '\033[0m'

# %%
def getDataFromPdf(pdf_path):
    pdf_reader = PyPDF2.PdfReader(pdf_path)
    num_pages = len(pdf_reader.pages)
    text = ''
    for page_num in range(num_pages):
        page = pdf_reader.pages[page_num]
        if page.extract_text():
            text += page.extract_text() + " "
    return text

# %%
def prepareChunks(text):
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Split text into chunks by sentences, respecting a maximum chunk size
    sentences = re.split(r'(?<=[.!?]) +', text)  # split on spaces following sentence-ending punctuation
    chunks = []
    current_chunk = ""
    for sentence in sentences:
        # Check if the current sentence plus the current chunk exceeds the limit
        if len(current_chunk) + len(sentence) + 1 < CHUNK_SIZE:  # +1 for the space
            current_chunk += (sentence + " ").strip()
        else:
            # When the chunk exceeds 1000 characters, store it and start a new one
            chunks.append(current_chunk)
            current_chunk = sentence + " "
    if current_chunk:  # Don't forget the last chunk!
        chunks.append(current_chunk)
    with open("vault.txt", "w", encoding="utf-8") as vault_file:
        for chunk in chunks:
            # Write each chunk to its own line
            vault_file.write(chunk.strip() + "\n\n")  # Two newlines to separate chunks
    print(f"PDF content stored to vault.txt with each chunk on a separate line.")
    return chunks

# %%
def prepareEmbeddings(chunks):
    print(NEON_GREEN + "Generating embeddings for the vault content..." + RESET_COLOR)
    vault_embeddings = []
    for chunk in chunks:
        try:
            response = ollama.embeddings(model='nomic-embed-text', prompt=chunk)
            embedding = response.get("embedding")
            if embedding:  # Ensure embedding is not None
                vault_embeddings.append(embedding)
            else:
                print(f"Skipping invalid embedding for content: {chunk.strip()}")
        except Exception as e:
            print(f"Failed to generate embedding for content: {chunk.strip()}. Error: {e}")

    if not vault_embeddings:
        print("No valid embeddings generated. Exiting...")
        exit(1)
    return vault_embeddings

# %%
def convertEmbeddingsToTensor(vault_embeddings):
    # Ensure all embeddings have the same size
    embedding_size = len(vault_embeddings[0])
    if any(len(e) != embedding_size for e in vault_embeddings):
        print("Embedding size mismatch detected. Skipping invalid embeddings...")
        vault_embeddings = [e for e in vault_embeddings if len(e) == embedding_size]

    # Convert to tensor
    vault_embeddings_tensor = torch.tensor(vault_embeddings)
    print("Embeddings for each line in the vault:")
    print(vault_embeddings_tensor)
    return vault_embeddings_tensor

# %%
def get_relevant_context(rewritten_input, vault_embeddings, vault_content, top_k=5):
    if not rewritten_input.strip():
        print("Rewritten input is empty. Skipping context retrieval.")
        return []

    if vault_embeddings.nelement() == 0:  # Check if the tensor has any elements
        print("Vault embeddings are empty. Skipping context retrieval.")
        return []

    try:
        input_embedding = ollama.embeddings(model='nomic-embed-text', prompt=rewritten_input)["embedding"]
    except Exception as e:
        print(f"Failed to generate input embedding. Error: {e}")
        return []

    if not input_embedding:
        print("Input embedding is invalid. Skipping context retrieval.")
        return []

    # Compute cosine similarity
    cos_scores = torch.cosine_similarity(torch.tensor(input_embedding).unsqueeze(0), vault_embeddings)

    # Adjust top_k if needed
    top_k = min(top_k, len(cos_scores))
    top_indices = torch.topk(cos_scores, k=top_k)[1].tolist()

    # Retrieve relevant context
    relevant_context = [vault_content[idx].strip() for idx in top_indices]
    return relevant_context

# %%
def getRelevantEmbeddings(query, embeddings, content):
    relevant_context = get_relevant_context(query, embeddings, content)
    if relevant_context:
        context_str = "\n".join(relevant_context)
        print("Context Pulled from Documents: \n\n" + CYAN + context_str + RESET_COLOR)
    else:
        print(CYAN + "No relevant context found." + RESET_COLOR)
    
    user_input_with_context = query
    if relevant_context:
        user_input_with_context = query + "\n\nRelevant Context:\n" + context_str

    conversation_history = []
    conversation_history.append({"role": "user", "content": user_input_with_context})


    system_message = "You are a helpful assistant that is an expert at extracting the most useful information from a given text. Also bring in extra relevant information to the user query from outside the given context."
    messages = [
        {"role": "system", "content": system_message}, 
        *conversation_history
    ]

    response = client.chat.completions.create(
        model='gemma:2b',
        messages=messages,
        max_tokens=3000,
    )
    print(response.choices[0].message.content)

# %%
client = OpenAI(
    base_url='http://localhost:11434/v1',
    api_key='gemma:2b'
)

# %%
text_data = getDataFromPdf("./Example_2.pdf")

# %%
text_data
# Out:
# "EX-10.1 2 hrmy-20230726xex10d1.htm EX-10.1\nExhibit 10.1\nEXECUTION VERSION\n   \nCREDIT AGREEMENT\ndated as of\nJuly 26, 2023\namong\nHARMONY BIOSCIENCES HOLDINGS, INC.,\nas Borrower\nThe Lenders Party Hereto\nJPMORGAN CHASE BANK, N.A.\nas Administrative Agent\nand\nJPMORGAN CHASE BANK, N.A.,\nas Bookrunner and Lead Arranger1/8/25, 10:05 AM sec.gov/Archives/edgar/data/1802665/000155837023012348/hrmy-20230726xex10d1.htm#_Toc256000083\nhttps://www.sec.gov/Archives/edgar/data/1802665/000155837023012348/hrmy-20230726xex10d1.htm#_Toc256000083 1/274 iTABLE OF CONTENTS\nPage\nArticle I Definitions 1\nSection 1.01Defined Terms 1\nSection 1.02Classification of Loans and Borrowings 45\nSection 1.03Terms Generally 45\nSection 1.04Accounting Terms; GAAP; Pro Forma Calculations 45\nSection 1.05Interest Rates; Benchmark Notification 46\nSection 1.06Leverage Ratios 47\nSection 1.07Divisions 47\nSection 1.08Limited Conditionality Transactions 47\nArticle II The Credits 48\nSection 2.01Commitments 48\nSection 2.02Loans and Borrowings 49\nSection 2.03Requests for Borrowings 49\nSection 2.04Intentionally Omitted 50\nSection 2.05Intentionally Omitted 50\nSection 2.06Intentionally Omitted 50\nSection 2.07Funding of Borrowings 50\nSection 2.08Interest Elections 50\nSection 2.09Termination of Commitments 51\nSection 2.10Repayment and Amortization of Loans; Evidence of Debt 51\nSection 2.11Prepayment of Loans 52\nSection 2.12Fees 54\nSection 2.13Interest 54\nSection 2.14Alternate Rate of Interest 55\nSection 2.15Increased Costs 57\nSection 2.16Break Funding Payments 58\nSection 2.17Taxes 59\nSection 2.18Payments Generally; Allocations of Proceeds; Pro Rata Treatment;\nSharing of Setoffs 62\nSection 2.19Mitigation Obligations; Replacement of Lenders 63\nSection 2.20Incremental Facilities 64\nSection 2.21Defaulting Lenders 67\nSection 2.22Refinancing Facilities. 68\nSection 2.23Extension of Term Loans. 69\nArticle III Representations and Warranties 71\nSection 3.01Organization; Powers; Subsidiaries 71\nSection 3.02Authorization; Enforceability 72\nSection 3.03Governmental Approvals; No Conflicts 72\nSection 3.04Financial Condition; No Material Adverse Change 72\nSection 3.05Properties 72\nSection 3.06Litigation, Environmental and Labor Matters 73\nSection 3.07Compliance with Laws and Agreements 73\nSection 3.08Investment Company Status 76\nSection 3.09Taxes 761/8/25, 10:05 AM sec.gov/Archives/edgar/data/1802665/000155837023012348/hrmy-20230726xex10d1.htm#_Toc256000083\nhttps://www.sec.gov/Archives/edgar/data/1802665/000155837023012348/hrmy-20230726xex10d1.htm#_Toc256000083 2/274 iiSection 3.10ERISA 76\nSection 3.11Disclosure 76\nSection 3.12Liens 77\nSection 3.13No Default 77\nSection 3.14No Burdensome Restrictions 77\nSection 3.15Solvency 77\nSection 3.16Insurance 77\nSection 3.17Security Interest in Collateral 77\nSection 3.18Anti-Corruption Laws and Sanctions 77\nSection 3.19Affected Financial Institutions 77\nSection 3.20Plan Assets; Prohibited Transactions 77\nSection 3.21Margin Regulations 78\nArticle IV Conditions 78\nSection 4.01Effective Date 78\nSection 4.02Each Credit Event 79\nArticle V Affirmative Covenants 80\nSection 5.01Financial Statements and Other Information 80\nSection 5.02Notices of Material Events 81\nSection 5.03Existence; Conduct of Business 82\nSection 5.04Payment of Obligations 82\nSection 5.05Maintenance of Properties; Insurance 82\nSection 5.06Books and Records; Inspection Rights 83\nSection 5.07Compliance with Laws and Material Contractual Obligations 83\nSection 5.08Use of Proceeds 84\nSection 5.09Subsidiary Guarantors; Pledges; Additional Collateral; Further\nAssurances 84\nSection 5.10Accuracy of Information 86\nArticle VI Negative Covenants 86\nSection 6.01Indebtedness 86\nSection 6.02Liens 89\nSection 6.03Fundamental Changes 92\nSection 6.04Dispositions 93\nSection 6.05Investments, Loans, Advances, Guarantees and Acquisitions 95\nSection 6.06Swap Agreements 97\nSection 6.07Transactions with Affiliates 98\nSection 6. ...

# %%
chunks = prepareChunks(text_data)
# Out:
# PDF content stored to vault.txt with each chunk on a separate line.

# %%
embeddings = prepareEmbeddings(chunks)
# Out:
# Generating embeddings for the vault content...

# %%
tensor_embedding = convertEmbeddingsToTensor(embeddings)
